# %% [markdown]
# # Natural Language Processing
# ## Xilin Tian

# %%
import os
import nltk
import nltk.corpus

# %%
print(os.listdir(nltk.data.find("corpora")))
# Out:
# ['abc', 'abc.zip', 'alpino', 'alpino.zip', 'biocreative_ppi', 'biocreative_ppi.zip', 'brown', 'brown.zip', 'brown_tei', 'brown_tei.zip', 'cess_cat', 'cess_cat.zip', 'cess_esp', 'cess_esp.zip', 'chat80', 'chat80.zip', 'city_database', 'city_database.zip', 'cmudict', 'cmudict.zip', 'comparative_sentences', 'comparative_sentences.zip', 'comtrans.zip', 'conll2000', 'conll2000.zip', 'conll2002', 'conll2002.zip', 'conll2007.zip', 'crubadan', 'crubadan.zip', 'dependency_treebank', 'dependency_treebank.zip', 'dolch', 'dolch.zip', 'europarl_raw', 'europarl_raw.zip', 'extended_omw', 'extended_omw.zip', 'floresta', 'floresta.zip', 'framenet_v15', 'framenet_v15.zip', 'framenet_v17', 'framenet_v17.zip', 'gazetteers', 'gazetteers.zip', 'genesis', 'genesis.zip', 'gutenberg', 'gutenberg.zip', 'ieer', 'ieer.zip', 'inaugural', 'inaugural.zip', 'indian', 'indian.zip', 'jeita.zip', 'kimmo', 'kimmo.zip', 'knbc.zip', 'lin_thesaurus', 'lin_thesaurus.zip', 'machado.zip', 'mac_morpho', 'mac_morpho.zip', 'masc_tagged.zip', 'movie_reviews', 'movie_reviews.zip', 'mte_teip5', 'mte_teip5.zip', 'names', 'names.zip', 'nombank.1.0.zip', 'nonbreaking_prefixes', 'nonbreaking_prefixes.zip', 'nps_chat', 'nps_chat.zip', 'omw', 'omw-1.4', 'omw-1.4.zip', 'omw.zip', 'opinion_lexicon', 'opinion_lexicon.zip', 'panlex_swadesh.zip', 'paradigms', 'paradigms.zip', 'pe08', 'pe08.zip', 'pil', 'pil.zip', 'pl196x', 'pl196x.zip', 'ppattach', 'ppattach.zip', 'problem_reports', 'problem_reports.zip', 'product_reviews_1', 'product_reviews_1.zip', 'product_reviews_2', 'product_reviews_2.zip', 'propbank.zip', 'pros_cons', 'pros_cons.zip', 'ptb', 'ptb.zip', 'qc', 'qc.zip', 'reuters.zip', 'rte', 'rte.zip', 'semcor.zip', 'senseval', 'senseval.zip', 'sentence_polarity', 'sentence_polarity.zip', 'sentiwordnet', 'sentiwordnet.zip', 'shakespeare', 'shakespeare.zip', 'sinica_treebank', 'sinica_treebank.zip', 'smultron', 'smultron.zip', 'state_union', 'state_union.zip', 'stopwords', 'stopwords.zip', 'subjectivity', 'subjectivity.zip', 'swadesh', 'swadesh.zip', 'switchboard', 'switchboard.zip', 'timit', 'timit.zip', 'toolbox', 'toolbox.zip', 'treebank', 'treebank.zip', 'twitter_samples', 'twitter_samples.zip', 'udhr', 'udhr.zip', 'udhr2', 'udhr2.zip', 'unicode_samples', 'unicode_samples.zip', 'universal_treebanks_v20.zip', 'verbnet', 'verbnet.zip', 'verbnet3', 'verbnet3.zip', 'webtext', 'webtext.zip', 'wordnet', 'wordnet.zip', 'wordnet2021', 'wordnet2021.zip', 'wordnet31', 'wordnet31.zip', 'wordnet_ic', 'wordnet_ic.zip', 'words', 'words.zip', 'ycoe', 'ycoe.zip']

# %%
from nltk.corpus import brown
brown.words()
# Out:
# ['The', 'Fulton', 'County', 'Grand', 'Jury', 'said', ...]

# %%
nltk.corpus.gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
hamlet = nltk.corpus.gutenberg.words('shakespeare-hamlet.txt')
hamlet
# Out:
# ['[', 'The', 'Tragedie', 'of', 'Hamlet', 'by', ...]

# %%
for word in hamlet[:500]:
    print(word, sep= ' ', end= ' ')
# Out:
# [ The Tragedie of Hamlet by William Shakespeare 1599 ] Actus Primus . Scoena Prima . Enter Barnardo and Francisco two Centinels . Barnardo . Who ' s there ? Fran . Nay answer me : Stand & vnfold your selfe Bar . Long liue the King Fran . Barnardo ? Bar . He Fran . You come most carefully vpon your houre Bar . ' Tis now strook twelue , get thee to bed Francisco Fran . For this releefe much thankes : ' Tis bitter cold , And I am sicke at heart Barn . Haue you had quiet Guard ? Fran . Not a Mouse stirring Barn . Well , goodnight . If you do meet Horatio and Marcellus , the Riuals of my Watch , bid them make hast . Enter Horatio and Marcellus . Fran . I thinke I heare them . Stand : who ' s there ? Hor . Friends to this ground Mar . And Leige - men to the Dane Fran . Giue you good night Mar . O farwel honest Soldier , who hath relieu ' d you ? Fra . Barnardo ha ' s my place : giue you goodnight . Exit Fran . Mar . Holla Barnardo Bar . Say , what is Horatio there ? Hor . A peece of him Bar . Welcome Horatio , welcome good Marcellus Mar . What , ha ' s this thing appear ' d againe to night Bar . I haue seene nothing Mar . Horatio saies , ' tis but our Fantasie , And will not let beleefe take hold of him Touching this dreaded sight , twice seene of vs , Therefore I haue intreated him along With vs , to watch the minutes of this Night , That if againe this Apparition come , He may approue our eyes , and speake to it Hor . Tush , tush , ' twill not appeare Bar . Sit downe a - while , And let vs once againe assaile your eares , That are so fortified against our Story , What we two Nights haue seene Hor . Well , sit we downe , And let vs heare Barnardo speake of this Barn . Last night of all , When yond same Starre that ' s Westward from the Pole Had made his course t ' illume that part of Heauen Where now it burnes , Marcellus and my selfe , The Bell then beating one Mar . Peace , breake thee of : Enter the Ghost . Looke where it comes againe Barn . In the same figure , like the King that ' s dead Mar . Thou art a Scholler ; speake to it Horatio Barn . Lookes it not like the King ? Marke it Horatio Hora . Most like : It harrowes me with fear & wonder Barn . It would be spoke too Mar . Question it Horatio Hor . What art

# %% [markdown]
# Input strings

# %%
AI = '''While a number of definitions of artificial intelligence (AI) have surfaced over the last few decades, John McCarthy offers the following definition in this 2004 paper (PDF, 106 KB) (link resides outside IBM), " It is the science and engineering of making intelligent machines, especially intelligent computer programs. It is related to the similar task of using computers to understand human intelligence, but AI does not have to confine itself to methods that are biologically observable."

However, decades before this definition, the birth of the artificial intelligence conversation was denoted by Alan Turing's seminal work, "Computing Machinery and Intelligence" (PDF, 89.8 KB) (link resides outside of IBM), which was published in 1950. In this paper, Turing, often referred to as the "father of computer science", asks the following question, "Can machines think?"  From there, he offers a test, now famously known as the "Turing Test", where a human interrogator would try to distinguish between a computer and human text response. While this test has undergone much scrutiny since its publish, it remains an important part of the history of AI as well as an ongoing concept within philosophy as it utilizes ideas around linguistics.

Stuart Russell and Peter Norvig then proceeded to publish, Artificial Intelligence: A Modern Approach (link resides outside IBM), becoming one of the leading textbooks in the study of AI. In it, they delve into four potential goals or definitions of AI, which differentiates computer systems on the basis of rationality and thinking vs. acting'''

# %%
type(AI)
# Out:
# str

# %%
from nltk.tokenize import word_tokenize

# %%
AI_tokens = word_tokenize(AI)
AI_tokens
# Out:
# ['While',
#  'a',
#  'number',
#  'of',
#  'definitions',
#  'of',
#  'artificial',
#  'intelligence',
#  '(',
#  'AI',
#  ')',
#  'have',
#  'surfaced',
#  'over',
#  'the',
#  'last',
#  'few',
#  'decades',
#  ',',
#  'John',
#  'McCarthy',
#  'offers',
#  'the',
#  'following',
#  'definition',
#  'in',
#  'this',
#  '2004',
#  'paper',
#  '(',
#  'PDF',
#  ',',
#  '106',
#  'KB',
#  ')',
#  '(',
#  'link',
#  'resides',
#  'outside',
#  'IBM',
#  ')',
#  ',',
#  '``',
#  'It',
#  'is',
#  'the',
#  'science',
#  'and',
#  'engineering',
#  'of',
#  'making',
#  'intelligent',
#  'machines',
#  ',',
#  'especially',
#  'intelligent',
#  'computer',
#  'programs',
#  '.',
#  'It',
#  'is',
#  'related',
#  'to',
#  'the',
#  'similar',
#  'task',
#  'of',
#  'using',
#  'computers',
#  'to',
#  'understand',
#  'human',
#  'intelligence',
#  ',',
#  'but',
#  'AI',
#  'does',
#  'not',
#  'have',
#  'to',
#  'confine',
#  'itself',
#  'to',
#  'methods',
#  'that',
#  'are',
#  'biologically',
#  'observable',
#  '.',
#  "''",
#  'However',
#  ',',
#  'decades',
#  'before',
#  'this',
#  'definition',
#  ',',
#  'the',
#  'birth',
#  'of',
#  'the',
#  'artificial',
#  'intelligence',
#  'conversation',
#  'was',
#  'denoted',
#  'by',
#  'Alan',
#  'Turing',
#  "'s",
#  'seminal',
#  'work',
#  ',',
#  '``',
#  'Computing',
#  'Machinery',
#  'and',
#  'Intelligence',
#  "''",
#  '(',
#  'PDF',
#  ',',
#  '89.8',
#  'KB',
#  ')',
#  '(',
#  'link',
#  'resides',
#  'outside',
#  'of',
#  'IBM',
#  ')',
#  ',',
#  'which',
#  'was',
#  'published',
#  'in',
#  '1950',
#  '.',
#  'In',
#  'this',
#  'paper',
#  ',',
#  'Turing',
#  ',',
#  'often',
#  'referred',
#  'to',
#  'as',
#  'the',
#  '``',
#  'father',
#  'of',
#  'computer',
#  'science',
#  "''",
#  ',',
#  'asks',
#  'the',
#  'following',
#  'question',
#  ',',
#  '``',
#  'Can',
#  'machines',
#  'think',
#  '?',
#  "''",
#  'From',
#  'there',
#  ',',
#  'he',
#  'offers',
#  'a',
#  'test',
#  ',',
#  'now',
#  'famously',
#  'known',
#  'as',
#  'the',
#  '``',
#  'Turing',
#  'Test',
#  "''",
#  ',',
#  'where',
#  'a',
#  'human',
#  'interrogator',
#  'would',
#  'try',
#  'to',
#  'distinguish',
#  'between',
#  'a',
#  'computer',
#  'and',
#  'human',
#  'text',
#  'response',
#  '.',
#  'While',
#  'this',
#  'test',
#  'has',
#  'undergone',
#  'much',
#  'scrutiny',
#  'since',
#  'its',
#  'publish',
#  ',',
#  'it',
#  'remains',
#  'an',
#  'important',
#  'part',
#  'of',
#  'the',
#  'history',
#  'of',
#  'AI',
#  'as',
#  'well',
#  'as',
#  'an',
#  'ongoing',
#  'concept',
#  'within',
#  'philosophy',
#  'as',
#  'it',
#  'utilizes',
#  'ideas',
#  'around',
#  'linguistics',
#  '.',
#  'Stuart',
#  'Russell',
#  'and',
#  'Peter',
#  'Norvig',
#  'then',
#  'proceeded',
#  'to',
#  'publish',
#  ',',
#  'Artificial',
#  'Intelligence',
#  ':',
#  'A',
#  'Modern',
#  'Approach',
#  '(',
#  'link',
#  'resides',
#  'outside',
#  'IBM',
#  ')',
#  ',',
#  'becoming',
#  'one',
#  'of',
#  'the',
#  'leading',
#  'textbooks',
#  'in',
#  'the',
#  'study',
#  'of',
#  'AI',
#  '.',
#  'In',
#  'it',
#  ',',
#  'they',
#  'delve',
#  'into',
#  'four',
#  'potential',
#  'goals',
#  'or',
#  'definitions',
#  'of',
#  'AI',
#  ',',
#  'which',
#  'differentiates',
#  'computer',
#  'systems',
#  'on',
#  'the',
#  'basis',
#  'of',
#  'rationality',
#  'and',
#  'thinking',
#  'vs.',
#  'acting']

# %%
len(AI_tokens)
# Out:
# 300

# %% [markdown]
# Frequency of words

# %%
from nltk.probability import FreqDist
fdist = FreqDist()

# %%
for word in AI_tokens:
    fdist[word.lower()]+=1
fdist
# Out:
# FreqDist({',': 22, 'of': 13, 'the': 13, 'to': 7, '(': 6, ')': 6, '.': 6, 'a': 5, 'intelligence': 5, 'ai': 5, ...})

# %%
fdist['artificial']
# Out:
# 3

# %% [markdown]
# Numbers of distinct words(tokens)

# %%
len(fdist)
# Out:
# 158

# %%
fdist_top10 = fdist.most_common(10)
fdist_top10
# Out:
# [(',', 22),
#  ('of', 13),
#  ('the', 13),
#  ('to', 7),
#  ('(', 6),
#  (')', 6),
#  ('.', 6),
#  ('a', 5),
#  ('intelligence', 5),
#  ('ai', 5)]

# %% [markdown]
# Numbers of paragraphs which are separated by a new line in our given document.

# %%
from nltk.tokenize import blankline_tokenize
AI_blank = blankline_tokenize(AI)
len(AI_blank)
# Out:
# 3

# %% [markdown]
# The 2nd paragraph

# %%
AI_blank[2]
# Out:
# 'Stuart Russell and Peter Norvig then proceeded to publish, Artificial Intelligence: A Modern Approach (link resides outside IBM), becoming one of the leading textbooks in the study of AI. In it, they delve into four potential goals or definitions of AI, which differentiates computer systems on the basis of rationality and thinking vs. acting'

# %% [markdown]
# Words Combination

# %%
from nltk.util import bigrams, trigrams, ngrams

# %%
quotes_bigrams = list(nltk.bigrams(AI_tokens))
quotes_bigrams
# Out:
# [('While', 'a'),
#  ('a', 'number'),
#  ('number', 'of'),
#  ('of', 'definitions'),
#  ('definitions', 'of'),
#  ('of', 'artificial'),
#  ('artificial', 'intelligence'),
#  ('intelligence', '('),
#  ('(', 'AI'),
#  ('AI', ')'),
#  (')', 'have'),
#  ('have', 'surfaced'),
#  ('surfaced', 'over'),
#  ('over', 'the'),
#  ('the', 'last'),
#  ('last', 'few'),
#  ('few', 'decades'),
#  ('decades', ','),
#  (',', 'John'),
#  ('John', 'McCarthy'),
#  ('McCarthy', 'offers'),
#  ('offers', 'the'),
#  ('the', 'following'),
#  ('following', 'definition'),
#  ('definition', 'in'),
#  ('in', 'this'),
#  ('this', '2004'),
#  ('2004', 'paper'),
#  ('paper', '('),
#  ('(', 'PDF'),
#  ('PDF', ','),
#  (',', '106'),
#  ('106', 'KB'),
#  ('KB', ')'),
#  (')', '('),
#  ('(', 'link'),
#  ('link', 'resides'),
#  ('resides', 'outside'),
#  ('outside', 'IBM'),
#  ('IBM', ')'),
#  (')', ','),
#  (',', '``'),
#  ('``', 'It'),
#  ('It', 'is'),
#  ('is', 'the'),
#  ('the', 'science'),
#  ('science', 'and'),
#  ('and', 'engineering'),
#  ('engineering', 'of'),
#  ('of', 'making'),
#  ('making', 'intelligent'),
#  ('intelligent', 'machines'),
#  ('machines', ','),
#  (',', 'especially'),
#  ('especially', 'intelligent'),
#  ('intelligent', 'computer'),
#  ('computer', 'programs'),
#  ('programs', '.'),
#  ('.', 'It'),
#  ('It', 'is'),
#  ('is', 'related'),
#  ('related', 'to'),
#  ('to', 'the'),
#  ('the', 'similar'),
#  ('similar', 'task'),
#  ('task', 'of'),
#  ('of', 'using'),
#  ('using', 'computers'),
#  ('computers', 'to'),
#  ('to', 'understand'),
#  ('understand', 'human'),
#  ('human', 'intelligence'),
#  ('intelligence', ','),
#  (',', 'but'),
#  ('but', 'AI'),
#  ('AI', 'does'),
#  ('does', 'not'),
#  ('not', 'have'),
#  ('have', 'to'),
#  ('to', 'confine'),
#  ('confine', 'itself'),
#  ('itself', 'to'),
#  ('to', 'methods'),
#  ('methods', 'that'),
#  ('that', 'are'),
#  ('are', 'biologically'),
#  ('biologically', 'observable'),
#  ('observable', '.'),
#  ('.', "''"),
#  ("''", 'However'),
#  ('However', ','),
#  (',', 'decades'),
#  ('decades', 'before'),
#  ('before', 'this'),
#  ('this', 'definition'),
#  ('definition', ','),
#  (',', 'the'),
#  ('the', 'birth'),
#  ('birth', 'of'),
#  ('of', 'the'),
#  ('the', 'artificial'),
#  ('artificial', 'intelligence'),
#  ('intelligence', 'conversation'),
#  ('conversation', 'was'),
#  ('was', 'denoted'),
#  ('denoted', 'by'),
#  ('by', 'Alan'),
#  ('Alan', 'Turing'),
#  ('Turing', "'s"),
#  ("'s", 'seminal'),
#  ('seminal', 'work'),
#  ('work', ','),
#  (',', '``'),
#  ('``', 'Computing'),
#  ('Computing', 'Machinery'),
#  ('Machinery', 'and'),
#  ('and', 'Intelligence'),
#  ('Intelligence', "''"),
#  ("''", '('),
#  ('(', 'PDF'),
#  ('PDF', ','),
#  (',', '89.8'),
#  ('89.8', 'KB'),
#  ('KB', ')'),
#  (')', '('),
#  ('(', 'link'),
#  ('link', 'resides'),
#  ('resides', 'outside'),
#  ('outside', 'of'),
#  ('of', 'IBM'),
#  ('IBM', ')'),
#  (')', ','),
#  (',', 'which'),
#  ('which', 'was'),
#  ('was', 'published'),
#  ('published', 'in'),
#  ('in', '1950'),
#  ('1950', '.'),
#  ('.', 'In'),
#  ('In', 'this'),
#  ('this', 'paper'),
#  ('paper', ','),
#  (',', 'Turing'),
#  ('Turing', ','),
#  (',', 'often'),
#  ('often', 'referred'),
#  ('referred', 'to'),
#  ('to', 'as'),
#  ('as', 'the'),
#  ('the', '``'),
#  ('``', 'father'),
#  ('father', 'of'),
#  ('of', 'computer'),
#  ('computer', 'science'),
#  ('science', "''"),
#  ("''", ','),
#  (',', 'asks'),
#  ('asks', 'the'),
#  ('the', 'following'),
#  ('following', 'question'),
#  ('question', ','),
#  (',', '``'),
#  ('``', 'Can'),
#  ('Can', 'machines'),
#  ('machines', 'think'),
#  ('think', '?'),
#  ('?', "''"),
#  ("''", 'From'),
#  ('From', 'there'),
#  ('there', ','),
#  (',', 'he'),
#  ('he', 'offers'),
#  ('offers', 'a'),
#  ('a', 'test'),
#  ('test', ','),
#  (',', 'now'),
#  ('now', 'famously'),
#  ('famously', 'known'),
#  ('known', 'as'),
#  ('as', 'the'),
#  ('the', '``'),
#  ('``', 'Turing'),
#  ('Turing', 'Test'),
#  ('Test', "''"),
#  ("''", ','),
#  (',', 'where'),
#  ('where', 'a'),
#  ('a', 'human'),
#  ('human', 'interrogator'),
#  ('interrogator', 'would'),
#  ('would', 'try'),
#  ('try', 'to'),
#  ('to', 'distinguish'),
#  ('distinguish', 'between'),
#  ('between', 'a'),
#  ('a', 'computer'),
#  ('computer', 'and'),
#  ('and', 'human'),
#  ('human', 'text'),
#  ('text', 'response'),
#  ('response', '.'),
#  ('.', 'While'),
#  ('While', 'this'),
#  ('this', 'test'),
#  ('test', 'has'),
#  ('has', 'undergone'),
#  ('undergone', 'much'),
#  ('much', 'scrutiny'),
#  ('scrutiny', 'since'),
#  ('since', 'its'),
#  ('its', 'publish'),
#  ('publish', ','),
#  (',', 'it'),
#  ('it', 'remains'),
#  ('remains', 'an'),
#  ('an', 'important'),
#  ('important', 'part'),
#  ('part', 'of'),
#  ('of', 'the'),
#  ('the', 'history'),
#  ('history', 'of'),
#  ('of', 'AI'),
#  ('AI', 'as'),
#  ('as', 'well'),
#  ('well', 'as'),
#  ('as', 'an'),
#  ('an', 'ongoing'),
#  ('ongoing', 'concept'),
#  ('concept', 'within'),
#  ('within', 'philosophy'),
#  ('philosophy', 'as'),
#  ('as', 'it'),
#  ('it', 'utilizes'),
#  ('utilizes', 'ideas'),
#  ('ideas', 'around'),
#  ('around', 'linguistics'),
#  ('linguistics', '.'),
#  ('.', 'Stuart'),
#  ('Stuart', 'Russell'),
#  ('Russell', 'and'),
#  ('and', 'Peter'),
#  ('Peter', 'Norvig'),
#  ('Norvig', 'then'),
#  ('then', 'proceeded'),
#  ('proceeded', 'to'),
#  ('to', 'publish'),
#  ('publish', ','),
#  (',', 'Artificial'),
#  ('Artificial', 'Intelligence'),
#  ('Intelligence', ':'),
#  (':', 'A'),
#  ('A', 'Modern'),
#  ('Modern', 'Approach'),
#  ('Approach', '('),
#  ('(', 'link'),
#  ('link', 'resides'),
#  ('resides', 'outside'),
#  ('outside', 'IBM'),
#  ('IBM', ')'),
#  (')', ','),
#  (',', 'becoming'),
#  ('becoming', 'one'),
#  ('one', 'of'),
#  ('of', 'the'),
#  ('the', 'leading'),
#  ('leading', 'textbooks'),
#  ('textbooks', 'in'),
#  ('in', 'the'),
#  ('the', 'study'),
#  ('study', 'of'),
#  ('of', 'AI'),
#  ('AI', '.'),
#  ('.', 'In'),
#  ('In', 'it'),
#  ('it', ','),
#  (',', 'they'),
#  ('they', 'delve'),
#  ('delve', 'into'),
#  ('into', 'four'),
#  ('four', 'potential'),
#  ('potential', 'goals'),
#  ('goals', 'or'),
#  ('or', 'definitions'),
#  ('definitions', 'of'),
#  ('of', 'AI'),
#  ('AI', ','),
#  (',', 'which'),
#  ('which', 'differentiates'),
#  ('differentiates', 'computer'),
#  ('computer', 'systems'),
#  ('systems', 'on'),
#  ('on', 'the'),
#  ('the', 'basis'),
#  ('basis', 'of'),
#  ('of', 'rationality'),
#  ('rationality', 'and'),
#  ('and', 'thinking'),
#  ('thinking', 'vs.'),
#  ('vs.', 'acting')]

# %%
quotes_trigrams = list(nltk.trigrams(AI_tokens))
quotes_trigrams
# Out:
# [('While', 'a', 'number'),
#  ('a', 'number', 'of'),
#  ('number', 'of', 'definitions'),
#  ('of', 'definitions', 'of'),
#  ('definitions', 'of', 'artificial'),
#  ('of', 'artificial', 'intelligence'),
#  ('artificial', 'intelligence', '('),
#  ('intelligence', '(', 'AI'),
#  ('(', 'AI', ')'),
#  ('AI', ')', 'have'),
#  (')', 'have', 'surfaced'),
#  ('have', 'surfaced', 'over'),
#  ('surfaced', 'over', 'the'),
#  ('over', 'the', 'last'),
#  ('the', 'last', 'few'),
#  ('last', 'few', 'decades'),
#  ('few', 'decades', ','),
#  ('decades', ',', 'John'),
#  (',', 'John', 'McCarthy'),
#  ('John', 'McCarthy', 'offers'),
#  ('McCarthy', 'offers', 'the'),
#  ('offers', 'the', 'following'),
#  ('the', 'following', 'definition'),
#  ('following', 'definition', 'in'),
#  ('definition', 'in', 'this'),
#  ('in', 'this', '2004'),
#  ('this', '2004', 'paper'),
#  ('2004', 'paper', '('),
#  ('paper', '(', 'PDF'),
#  ('(', 'PDF', ','),
#  ('PDF', ',', '106'),
#  (',', '106', 'KB'),
#  ('106', 'KB', ')'),
#  ('KB', ')', '('),
#  (')', '(', 'link'),
#  ('(', 'link', 'resides'),
#  ('link', 'resides', 'outside'),
#  ('resides', 'outside', 'IBM'),
#  ('outside', 'IBM', ')'),
#  ('IBM', ')', ','),
#  (')', ',', '``'),
#  (',', '``', 'It'),
#  ('``', 'It', 'is'),
#  ('It', 'is', 'the'),
#  ('is', 'the', 'science'),
#  ('the', 'science', 'and'),
#  ('science', 'and', 'engineering'),
#  ('and', 'engineering', 'of'),
#  ('engineering', 'of', 'making'),
#  ('of', 'making', 'intelligent'),
#  ('making', 'intelligent', 'machines'),
#  ('intelligent', 'machines', ','),
#  ('machines', ',', 'especially'),
#  (',', 'especially', 'intelligent'),
#  ('especially', 'intelligent', 'computer'),
#  ('intelligent', 'computer', 'programs'),
#  ('computer', 'programs', '.'),
#  ('programs', '.', 'It'),
#  ('.', 'It', 'is'),
#  ('It', 'is', 'related'),
#  ('is', 'related', 'to'),
#  ('related', 'to', 'the'),
#  ('to', 'the', 'similar'),
#  ('the', 'similar', 'task'),
#  ('similar', 'task', 'of'),
#  ('task', 'of', 'using'),
#  ('of', 'using', 'computers'),
#  ('using', 'computers', 'to'),
#  ('computers', 'to', 'understand'),
#  ('to', 'understand', 'human'),
#  ('understand', 'human', 'intelligence'),
#  ('human', 'intelligence', ','),
#  ('intelligence', ',', 'but'),
#  (',', 'but', 'AI'),
#  ('but', 'AI', 'does'),
#  ('AI', 'does', 'not'),
#  ('does', 'not', 'have'),
#  ('not', 'have', 'to'),
#  ('have', 'to', 'confine'),
#  ('to', 'confine', 'itself'),
#  ('confine', 'itself', 'to'),
#  ('itself', 'to', 'methods'),
#  ('to', 'methods', 'that'),
#  ('methods', 'that', 'are'),
#  ('that', 'are', 'biologically'),
#  ('are', 'biologically', 'observable'),
#  ('biologically', 'observable', '.'),
#  ('observable', '.', "''"),
#  ('.', "''", 'However'),
#  ("''", 'However', ','),
#  ('However', ',', 'decades'),
#  (',', 'decades', 'before'),
#  ('decades', 'before', 'this'),
#  ('before', 'this', 'definition'),
#  ('this', 'definition', ','),
#  ('definition', ',', 'the'),
#  (',', 'the', 'birth'),
#  ('the', 'birth', 'of'),
#  ('birth', 'of', 'the'),
#  ('of', 'the', 'artificial'),
#  ('the', 'artificial', 'intelligence'),
#  ('artificial', 'intelligence', 'conversation'),
#  ('intelligence', 'conversation', 'was'),
#  ('conversation', 'was', 'denoted'),
#  ('was', 'denoted', 'by'),
#  ('denoted', 'by', 'Alan'),
#  ('by', 'Alan', 'Turing'),
#  ('Alan', 'Turing', "'s"),
#  ('Turing', "'s", 'seminal'),
#  ("'s", 'seminal', 'work'),
#  ('seminal', 'work', ','),
#  ('work', ',', '``'),
#  (',', '``', 'Computing'),
#  ('``', 'Computing', 'Machinery'),
#  ('Computing', 'Machinery', 'and'),
#  ('Machinery', 'and', 'Intelligence'),
#  ('and', 'Intelligence', "''"),
#  ('Intelligence', "''", '('),
#  ("''", '(', 'PDF'),
#  ('(', 'PDF', ','),
#  ('PDF', ',', '89.8'),
#  (',', '89.8', 'KB'),
#  ('89.8', 'KB', ')'),
#  ('KB', ')', '('),
#  (')', '(', 'link'),
#  ('(', 'link', 'resides'),
#  ('link', 'resides', 'outside'),
#  ('resides', 'outside', 'of'),
#  ('outside', 'of', 'IBM'),
#  ('of', 'IBM', ')'),
#  ('IBM', ')', ','),
#  (')', ',', 'which'),
#  (',', 'which', 'was'),
#  ('which', 'was', 'published'),
#  ('was', 'published', 'in'),
#  ('published', 'in', '1950'),
#  ('in', '1950', '.'),
#  ('1950', '.', 'In'),
#  ('.', 'In', 'this'),
#  ('In', 'this', 'paper'),
#  ('this', 'paper', ','),
#  ('paper', ',', 'Turing'),
#  (',', 'Turing', ','),
#  ('Turing', ',', 'often'),
#  (',', 'often', 'referred'),
#  ('often', 'referred', 'to'),
#  ('referred', 'to', 'as'),
#  ('to', 'as', 'the'),
#  ('as', 'the', '``'),
#  ('the', '``', 'father'),
#  ('``', 'father', 'of'),
#  ('father', 'of', 'computer'),
#  ('of', 'computer', 'science'),
#  ('computer', 'science', "''"),
#  ('science', "''", ','),
#  ("''", ',', 'asks'),
#  (',', 'asks', 'the'),
#  ('asks', 'the', 'following'),
#  ('the', 'following', 'question'),
#  ('following', 'question', ','),
#  ('question', ',', '``'),
#  (',', '``', 'Can'),
#  ('``', 'Can', 'machines'),
#  ('Can', 'machines', 'think'),
#  ('machines', 'think', '?'),
#  ('think', '?', "''"),
#  ('?', "''", 'From'),
#  ("''", 'From', 'there'),
#  ('From', 'there', ','),
#  ('there', ',', 'he'),
#  (',', 'he', 'offers'),
#  ('he', 'offers', 'a'),
#  ('offers', 'a', 'test'),
#  ('a', 'test', ','),
#  ('test', ',', 'now'),
#  (',', 'now', 'famously'),
#  ('now', 'famously', 'known'),
#  ('famously', 'known', 'as'),
#  ('known', 'as', 'the'),
#  ('as', 'the', '``'),
#  ('the', '``', 'Turing'),
#  ('``', 'Turing', 'Test'),
#  ('Turing', 'Test', "''"),
#  ('Test', "''", ','),
#  ("''", ',', 'where'),
#  (',', 'where', 'a'),
#  ('where', 'a', 'human'),
#  ('a', 'human', 'interrogator'),
#  ('human', 'interrogator', 'would'),
#  ('interrogator', 'would', 'try'),
#  ('would', 'try', 'to'),
#  ('try', 'to', 'distinguish'),
#  ('to', 'distinguish', 'between'),
#  ('distinguish', 'between', 'a'),
#  ('between', 'a', 'computer'),
#  ('a', 'computer', 'and'),
#  ('computer', 'and', 'human'),
#  ('and', 'human', 'text'),
#  ('human', 'text', 'response'),
#  ('text', 'response', '.'),
#  ('response', '.', 'While'),
#  ('.', 'While', 'this'),
#  ('While', 'this', 'test'),
#  ('this', 'test', 'has'),
#  ('test', 'has', 'undergone'),
#  ('has', 'undergone', 'much'),
#  ('undergone', 'much', 'scrutiny'),
#  ('much', 'scrutiny', 'since'),
#  ('scrutiny', 'since', 'its'),
#  ('since', 'its', 'publish'),
#  ('its', 'publish', ','),
#  ('publish', ',', 'it'),
#  (',', 'it', 'remains'),
#  ('it', 'remains', 'an'),
#  ('remains', 'an', 'important'),
#  ('an', 'important', 'part'),
#  ('important', 'part', 'of'),
#  ('part', 'of', 'the'),
#  ('of', 'the', 'history'),
#  ('the', 'history', 'of'),
#  ('history', 'of', 'AI'),
#  ('of', 'AI', 'as'),
#  ('AI', 'as', 'well'),
#  ('as', 'well', 'as'),
#  ('well', 'as', 'an'),
#  ('as', 'an', 'ongoing'),
#  ('an', 'ongoing', 'concept'),
#  ('ongoing', 'concept', 'within'),
#  ('concept', 'within', 'philosophy'),
#  ('within', 'philosophy', 'as'),
#  ('philosophy', 'as', 'it'),
#  ('as', 'it', 'utilizes'),
#  ('it', 'utilizes', 'ideas'),
#  ('utilizes', 'ideas', 'around'),
#  ('ideas', 'around', 'linguistics'),
#  ('around', 'linguistics', '.'),
#  ('linguistics', '.', 'Stuart'),
#  ('.', 'Stuart', 'Russell'),
#  ('Stuart', 'Russell', 'and'),
#  ('Russell', 'and', 'Peter'),
#  ('and', 'Peter', 'Norvig'),
#  ('Peter', 'Norvig', 'then'),
#  ('Norvig', 'then', 'proceeded'),
#  ('then', 'proceeded', 'to'),
#  ('proceeded', 'to', 'publish'),
#  ('to', 'publish', ','),
#  ('publish', ',', 'Artificial'),
#  (',', 'Artificial', 'Intelligence'),
#  ('Artificial', 'Intelligence', ':'),
#  ('Intelligence', ':', 'A'),
#  (':', 'A', 'Modern'),
#  ('A', 'Modern', 'Approach'),
#  ('Modern', 'Approach', '('),
#  ('Approach', '(', 'link'),
#  ('(', 'link', 'resides'),
#  ('link', 'resides', 'outside'),
#  ('resides', 'outside', 'IBM'),
#  ('outside', 'IBM', ')'),
#  ('IBM', ')', ','),
#  (')', ',', 'becoming'),
#  (',', 'becoming', 'one'),
#  ('becoming', 'one', 'of'),
#  ('one', 'of', 'the'),
#  ('of', 'the', 'leading'),
#  ('the', 'leading', 'textbooks'),
#  ('leading', 'textbooks', 'in'),
#  ('textbooks', 'in', 'the'),
#  ('in', 'the', 'study'),
#  ('the', 'study', 'of'),
#  ('study', 'of', 'AI'),
#  ('of', 'AI', '.'),
#  ('AI', '.', 'In'),
#  ('.', 'In', 'it'),
#  ('In', 'it', ','),
#  ('it', ',', 'they'),
#  (',', 'they', 'delve'),
#  ('they', 'delve', 'into'),
#  ('delve', 'into', 'four'),
#  ('into', 'four', 'potential'),
#  ('four', 'potential', 'goals'),
#  ('potential', 'goals', 'or'),
#  ('goals', 'or', 'definitions'),
#  ('or', 'definitions', 'of'),
#  ('definitions', 'of', 'AI'),
#  ('of', 'AI', ','),
#  ('AI', ',', 'which'),
#  (',', 'which', 'differentiates'),
#  ('which', 'differentiates', 'computer'),
#  ('differentiates', 'computer', 'systems'),
#  ('computer', 'systems', 'on'),
#  ('systems', 'on', 'the'),
#  ('on', 'the', 'basis'),
#  ('the', 'basis', 'of'),
#  ('basis', 'of', 'rationality'),
#  ('of', 'rationality', 'and'),
#  ('rationality', 'and', 'thinking'),
#  ('and', 'thinking', 'vs.'),
#  ('thinking', 'vs.', 'acting')]

# %%
quotes_ngrams = list(nltk.ngrams(AI_tokens, 5))
quotes_ngrams
# Out:
# [('While', 'a', 'number', 'of', 'definitions'),
#  ('a', 'number', 'of', 'definitions', 'of'),
#  ('number', 'of', 'definitions', 'of', 'artificial'),
#  ('of', 'definitions', 'of', 'artificial', 'intelligence'),
#  ('definitions', 'of', 'artificial', 'intelligence', '('),
#  ('of', 'artificial', 'intelligence', '(', 'AI'),
#  ('artificial', 'intelligence', '(', 'AI', ')'),
#  ('intelligence', '(', 'AI', ')', 'have'),
#  ('(', 'AI', ')', 'have', 'surfaced'),
#  ('AI', ')', 'have', 'surfaced', 'over'),
#  (')', 'have', 'surfaced', 'over', 'the'),
#  ('have', 'surfaced', 'over', 'the', 'last'),
#  ('surfaced', 'over', 'the', 'last', 'few'),
#  ('over', 'the', 'last', 'few', 'decades'),
#  ('the', 'last', 'few', 'decades', ','),
#  ('last', 'few', 'decades', ',', 'John'),
#  ('few', 'decades', ',', 'John', 'McCarthy'),
#  ('decades', ',', 'John', 'McCarthy', 'offers'),
#  (',', 'John', 'McCarthy', 'offers', 'the'),
#  ('John', 'McCarthy', 'offers', 'the', 'following'),
#  ('McCarthy', 'offers', 'the', 'following', 'definition'),
#  ('offers', 'the', 'following', 'definition', 'in'),
#  ('the', 'following', 'definition', 'in', 'this'),
#  ('following', 'definition', 'in', 'this', '2004'),
#  ('definition', 'in', 'this', '2004', 'paper'),
#  ('in', 'this', '2004', 'paper', '('),
#  ('this', '2004', 'paper', '(', 'PDF'),
#  ('2004', 'paper', '(', 'PDF', ','),
#  ('paper', '(', 'PDF', ',', '106'),
#  ('(', 'PDF', ',', '106', 'KB'),
#  ('PDF', ',', '106', 'KB', ')'),
#  (',', '106', 'KB', ')', '('),
#  ('106', 'KB', ')', '(', 'link'),
#  ('KB', ')', '(', 'link', 'resides'),
#  (')', '(', 'link', 'resides', 'outside'),
#  ('(', 'link', 'resides', 'outside', 'IBM'),
#  ('link', 'resides', 'outside', 'IBM', ')'),
#  ('resides', 'outside', 'IBM', ')', ','),
#  ('outside', 'IBM', ')', ',', '``'),
#  ('IBM', ')', ',', '``', 'It'),
#  (')', ',', '``', 'It', 'is'),
#  (',', '``', 'It', 'is', 'the'),
#  ('``', 'It', 'is', 'the', 'science'),
#  ('It', 'is', 'the', 'science', 'and'),
#  ('is', 'the', 'science', 'and', 'engineering'),
#  ('the', 'science', 'and', 'engineering', 'of'),
#  ('science', 'and', 'engineering', 'of', 'making'),
#  ('and', 'engineering', 'of', 'making', 'intelligent'),
#  ('engineering', 'of', 'making', 'intelligent', 'machines'),
#  ('of', 'making', 'intelligent', 'machines', ','),
#  ('making', 'intelligent', 'machines', ',', 'especially'),
#  ('intelligent', 'machines', ',', 'especially', 'intelligent'),
#  ('machines', ',', 'especially', 'intelligent', 'computer'),
#  (',', 'especially', 'intelligent', 'computer', 'programs'),
#  ('especially', 'intelligent', 'computer', 'programs', '.'),
#  ('intelligent', 'computer', 'programs', '.', 'It'),
#  ('computer', 'programs', '.', 'It', 'is'),
#  ('programs', '.', 'It', 'is', 'related'),
#  ('.', 'It', 'is', 'related', 'to'),
#  ('It', 'is', 'related', 'to', 'the'),
#  ('is', 'related', 'to', 'the', 'similar'),
#  ('related', 'to', 'the', 'similar', 'task'),
#  ('to', 'the', 'similar', 'task', 'of'),
#  ('the', 'similar', 'task', 'of', 'using'),
#  ('similar', 'task', 'of', 'using', 'computers'),
#  ('task', 'of', 'using', 'computers', 'to'),
#  ('of', 'using', 'computers', 'to', 'understand'),
#  ('using', 'computers', 'to', 'understand', 'human'),
#  ('computers', 'to', 'understand', 'human', 'intelligence'),
#  ('to', 'understand', 'human', 'intelligence', ','),
#  ('understand', 'human', 'intelligence', ',', 'but'),
#  ('human', 'intelligence', ',', 'but', 'AI'),
#  ('intelligence', ',', 'but', 'AI', 'does'),
#  (',', 'but', 'AI', 'does', 'not'),
#  ('but', 'AI', 'does', 'not', 'have'),
#  ('AI', 'does', 'not', 'have', 'to'),
#  ('does', 'not', 'have', 'to', 'confine'),
#  ('not', 'have', 'to', 'confine', 'itself'),
#  ('have', 'to', 'confine', 'itself', 'to'),
#  ('to', 'confine', 'itself', 'to', 'methods'),
#  ('confine', 'itself', 'to', 'methods', 'that'),
#  ('itself', 'to', 'methods', 'that', 'are'),
#  ('to', 'methods', 'that', 'are', 'biologically'),
#  ('methods', 'that', 'are', 'biologically', 'observable'),
#  ('that', 'are', 'biologically', 'observable', '.'),
#  ('are', 'biologically', 'observable', '.', "''"),
#  ('biologically', 'observable', '.', "''", 'However'),
#  ('observable', '.', "''", 'However', ','),
#  ('.', "''", 'However', ',', 'decades'),
#  ("''", 'However', ',', 'decades', 'before'),
#  ('However', ',', 'decades', 'before', 'this'),
#  (',', 'decades', 'before', 'this', 'definition'),
#  ('decades', 'before', 'this', 'definition', ','),
#  ('before', 'this', 'definition', ',', 'the'),
#  ('this', 'definition', ',', 'the', 'birth'),
#  ('definition', ',', 'the', 'birth', 'of'),
#  (',', 'the', 'birth', 'of', 'the'),
#  ('the', 'birth', 'of', 'the', 'artificial'),
#  ('birth', 'of', 'the', 'artificial', 'intelligence'),
#  ('of', 'the', 'artificial', 'intelligence', 'conversation'),
#  ('the', 'artificial', 'intelligence', 'conversation', 'was'),
#  ('artificial', 'intelligence', 'conversation', 'was', 'denoted'),
#  ('intelligence', 'conversation', 'was', 'denoted', 'by'),
#  ('conversation', 'was', 'denoted', 'by', 'Alan'),
#  ('was', 'denoted', 'by', 'Alan', 'Turing'),
#  ('denoted', 'by', 'Alan', 'Turing', "'s"),
#  ('by', 'Alan', 'Turing', "'s", 'seminal'),
#  ('Alan', 'Turing', "'s", 'seminal', 'work'),
#  ('Turing', "'s", 'seminal', 'work', ','),
#  ("'s", 'seminal', 'work', ',', '``'),
#  ('seminal', 'work', ',', '``', 'Computing'),
#  ('work', ',', '``', 'Computing', 'Machinery'),
#  (',', '``', 'Computing', 'Machinery', 'and'),
#  ('``', 'Computing', 'Machinery', 'and', 'Intelligence'),
#  ('Computing', 'Machinery', 'and', 'Intelligence', "''"),
#  ('Machinery', 'and', 'Intelligence', "''", '('),
#  ('and', 'Intelligence', "''", '(', 'PDF'),
#  ('Intelligence', "''", '(', 'PDF', ','),
#  ("''", '(', 'PDF', ',', '89.8'),
#  ('(', 'PDF', ',', '89.8', 'KB'),
#  ('PDF', ',', '89.8', 'KB', ')'),
#  (',', '89.8', 'KB', ')', '('),
#  ('89.8', 'KB', ')', '(', 'link'),
#  ('KB', ')', '(', 'link', 'resides'),
#  (')', '(', 'link', 'resides', 'outside'),
#  ('(', 'link', 'resides', 'outside', 'of'),
#  ('link', 'resides', 'outside', 'of', 'IBM'),
#  ('resides', 'outside', 'of', 'IBM', ')'),
#  ('outside', 'of', 'IBM', ')', ','),
#  ('of', 'IBM', ')', ',', 'which'),
#  ('IBM', ')', ',', 'which', 'was'),
#  (')', ',', 'which', 'was', 'published'),
#  (',', 'which', 'was', 'published', 'in'),
#  ('which', 'was', 'published', 'in', '1950'),
#  ('was', 'published', 'in', '1950', '.'),
#  ('published', 'in', '1950', '.', 'In'),
#  ('in', '1950', '.', 'In', 'this'),
#  ('1950', '.', 'In', 'this', 'paper'),
#  ('.', 'In', 'this', 'paper', ','),
#  ('In', 'this', 'paper', ',', 'Turing'),
#  ('this', 'paper', ',', 'Turing', ','),
#  ('paper', ',', 'Turing', ',', 'often'),
#  (',', 'Turing', ',', 'often', 'referred'),
#  ('Turing', ',', 'often', 'referred', 'to'),
#  (',', 'often', 'referred', 'to', 'as'),
#  ('often', 'referred', 'to', 'as', 'the'),
#  ('referred', 'to', 'as', 'the', '``'),
#  ('to', 'as', 'the', '``', 'father'),
#  ('as', 'the', '``', 'father', 'of'),
#  ('the', '``', 'father', 'of', 'computer'),
#  ('``', 'father', 'of', 'computer', 'science'),
#  ('father', 'of', 'computer', 'science', "''"),
#  ('of', 'computer', 'science', "''", ','),
#  ('computer', 'science', "''", ',', 'asks'),
#  ('science', "''", ',', 'asks', 'the'),
#  ("''", ',', 'asks', 'the', 'following'),
#  (',', 'asks', 'the', 'following', 'question'),
#  ('asks', 'the', 'following', 'question', ','),
#  ('the', 'following', 'question', ',', '``'),
#  ('following', 'question', ',', '``', 'Can'),
#  ('question', ',', '``', 'Can', 'machines'),
#  (',', '``', 'Can', 'machines', 'think'),
#  ('``', 'Can', 'machines', 'think', '?'),
#  ('Can', 'machines', 'think', '?', "''"),
#  ('machines', 'think', '?', "''", 'From'),
#  ('think', '?', "''", 'From', 'there'),
#  ('?', "''", 'From', 'there', ','),
#  ("''", 'From', 'there', ',', 'he'),
#  ('From', 'there', ',', 'he', 'offers'),
#  ('there', ',', 'he', 'offers', 'a'),
#  (',', 'he', 'offers', 'a', 'test'),
#  ('he', 'offers', 'a', 'test', ','),
#  ('offers', 'a', 'test', ',', 'now'),
#  ('a', 'test', ',', 'now', 'famously'),
#  ('test', ',', 'now', 'famously', 'known'),
#  (',', 'now', 'famously', 'known', 'as'),
#  ('now', 'famously', 'known', 'as', 'the'),
#  ('famously', 'known', 'as', 'the', '``'),
#  ('known', 'as', 'the', '``', 'Turing'),
#  ('as', 'the', '``', 'Turing', 'Test'),
#  ('the', '``', 'Turing', 'Test', "''"),
#  ('``', 'Turing', 'Test', "''", ','),
#  ('Turing', 'Test', "''", ',', 'where'),
#  ('Test', "''", ',', 'where', 'a'),
#  ("''", ',', 'where', 'a', 'human'),
#  (',', 'where', 'a', 'human', 'interrogator'),
#  ('where', 'a', 'human', 'interrogator', 'would'),
#  ('a', 'human', 'interrogator', 'would', 'try'),
#  ('human', 'interrogator', 'would', 'try', 'to'),
#  ('interrogator', 'would', 'try', 'to', 'distinguish'),
#  ('would', 'try', 'to', 'distinguish', 'between'),
#  ('try', 'to', 'distinguish', 'between', 'a'),
#  ('to', 'distinguish', 'between', 'a', 'computer'),
#  ('distinguish', 'between', 'a', 'computer', 'and'),
#  ('between', 'a', 'computer', 'and', 'human'),
#  ('a', 'computer', 'and', 'human', 'text'),
#  ('computer', 'and', 'human', 'text', 'response'),
#  ('and', 'human', 'text', 'response', '.'),
#  ('human', 'text', 'response', '.', 'While'),
#  ('text', 'response', '.', 'While', 'this'),
#  ('response', '.', 'While', 'this', 'test'),
#  ('.', 'While', 'this', 'test', 'has'),
#  ('While', 'this', 'test', 'has', 'undergone'),
#  ('this', 'test', 'has', 'undergone', 'much'),
#  ('test', 'has', 'undergone', 'much', 'scrutiny'),
#  ('has', 'undergone', 'much', 'scrutiny', 'since'),
#  ('undergone', 'much', 'scrutiny', 'since', 'its'),
#  ('much', 'scrutiny', 'since', 'its', 'publish'),
#  ('scrutiny', 'since', 'its', 'publish', ','),
#  ('since', 'its', 'publish', ',', 'it'),
#  ('its', 'publish', ',', 'it', 'remains'),
#  ('publish', ',', 'it', 'remains', 'an'),
#  (',', 'it', 'remains', 'an', 'important'),
#  ('it', 'remains', 'an', 'important', 'part'),
#  ('remains', 'an', 'important', 'part', 'of'),
#  ('an', 'important', 'part', 'of', 'the'),
#  ('important', 'part', 'of', 'the', 'history'),
#  ('part', 'of', 'the', 'history', 'of'),
#  ('of', 'the', 'history', 'of', 'AI'),
#  ('the', 'history', 'of', 'AI', 'as'),
#  ('history', 'of', 'AI', 'as', 'well'),
#  ('of', 'AI', 'as', 'well', 'as'),
#  ('AI', 'as', 'well', 'as', 'an'),
#  ('as', 'well', 'as', 'an', 'ongoing'),
#  ('well', 'as', 'an', 'ongoing', 'concept'),
#  ('as', 'an', 'ongoing', 'concept', 'within'),
#  ('an', 'ongoing', 'concept', 'within', 'philosophy'),
#  ('ongoing', 'concept', 'within', 'philosophy', 'as'),
#  ('concept', 'within', 'philosophy', 'as', 'it'),
#  ('within', 'philosophy', 'as', 'it', 'utilizes'),
#  ('philosophy', 'as', 'it', 'utilizes', 'ideas'),
#  ('as', 'it', 'utilizes', 'ideas', 'around'),
#  ('it', 'utilizes', 'ideas', 'around', 'linguistics'),
#  ('utilizes', 'ideas', 'around', 'linguistics', '.'),
#  ('ideas', 'around', 'linguistics', '.', 'Stuart'),
#  ('around', 'linguistics', '.', 'Stuart', 'Russell'),
#  ('linguistics', '.', 'Stuart', 'Russell', 'and'),
#  ('.', 'Stuart', 'Russell', 'and', 'Peter'),
#  ('Stuart', 'Russell', 'and', 'Peter', 'Norvig'),
#  ('Russell', 'and', 'Peter', 'Norvig', 'then'),
#  ('and', 'Peter', 'Norvig', 'then', 'proceeded'),
#  ('Peter', 'Norvig', 'then', 'proceeded', 'to'),
#  ('Norvig', 'then', 'proceeded', 'to', 'publish'),
#  ('then', 'proceeded', 'to', 'publish', ','),
#  ('proceeded', 'to', 'publish', ',', 'Artificial'),
#  ('to', 'publish', ',', 'Artificial', 'Intelligence'),
#  ('publish', ',', 'Artificial', 'Intelligence', ':'),
#  (',', 'Artificial', 'Intelligence', ':', 'A'),
#  ('Artificial', 'Intelligence', ':', 'A', 'Modern'),
#  ('Intelligence', ':', 'A', 'Modern', 'Approach'),
#  (':', 'A', 'Modern', 'Approach', '('),
#  ('A', 'Modern', 'Approach', '(', 'link'),
#  ('Modern', 'Approach', '(', 'link', 'resides'),
#  ('Approach', '(', 'link', 'resides', 'outside'),
#  ('(', 'link', 'resides', 'outside', 'IBM'),
#  ('link', 'resides', 'outside', 'IBM', ')'),
#  ('resides', 'outside', 'IBM', ')', ','),
#  ('outside', 'IBM', ')', ',', 'becoming'),
#  ('IBM', ')', ',', 'becoming', 'one'),
#  (')', ',', 'becoming', 'one', 'of'),
#  (',', 'becoming', 'one', 'of', 'the'),
#  ('becoming', 'one', 'of', 'the', 'leading'),
#  ('one', 'of', 'the', 'leading', 'textbooks'),
#  ('of', 'the', 'leading', 'textbooks', 'in'),
#  ('the', 'leading', 'textbooks', 'in', 'the'),
#  ('leading', 'textbooks', 'in', 'the', 'study'),
#  ('textbooks', 'in', 'the', 'study', 'of'),
#  ('in', 'the', 'study', 'of', 'AI'),
#  ('the', 'study', 'of', 'AI', '.'),
#  ('study', 'of', 'AI', '.', 'In'),
#  ('of', 'AI', '.', 'In', 'it'),
#  ('AI', '.', 'In', 'it', ','),
#  ('.', 'In', 'it', ',', 'they'),
#  ('In', 'it', ',', 'they', 'delve'),
#  ('it', ',', 'they', 'delve', 'into'),
#  (',', 'they', 'delve', 'into', 'four'),
#  ('they', 'delve', 'into', 'four', 'potential'),
#  ('delve', 'into', 'four', 'potential', 'goals'),
#  ('into', 'four', 'potential', 'goals', 'or'),
#  ('four', 'potential', 'goals', 'or', 'definitions'),
#  ('potential', 'goals', 'or', 'definitions', 'of'),
#  ('goals', 'or', 'definitions', 'of', 'AI'),
#  ('or', 'definitions', 'of', 'AI', ','),
#  ('definitions', 'of', 'AI', ',', 'which'),
#  ('of', 'AI', ',', 'which', 'differentiates'),
#  ('AI', ',', 'which', 'differentiates', 'computer'),
#  (',', 'which', 'differentiates', 'computer', 'systems'),
#  ('which', 'differentiates', 'computer', 'systems', 'on'),
#  ('differentiates', 'computer', 'systems', 'on', 'the'),
#  ('computer', 'systems', 'on', 'the', 'basis'),
#  ('systems', 'on', 'the', 'basis', 'of'),
#  ('on', 'the', 'basis', 'of', 'rationality'),
#  ('the', 'basis', 'of', 'rationality', 'and'),
#  ('basis', 'of', 'rationality', 'and', 'thinking'),
#  ('of', 'rationality', 'and', 'thinking', 'vs.'),
#  ('rationality', 'and', 'thinking', 'vs.', 'acting')]

# %% [markdown]
# Stemming: Normalize words into its base form or eoot form

# %%
from nltk.stem import PorterStemmer
pst = PorterStemmer()

# %%
pst.stem("having")
# Out:
# 'have'

# %%
words_to_stem = ["give",'giving','given','gave']
for words in words_to_stem:
    print(words+':'+pst.stem(words))
# Out:
# give:give
# giving:give
# given:given
# gave:gave

# %% [markdown]
# Another stemmer

# %%
from nltk.stem import LancasterStemmer
lst = LancasterStemmer()
for words in words_to_stem:
    print(words+':'+lst.stem(words))
# Out:
# give:giv
# giving:giv
# given:giv
# gave:gav

# %% [markdown]
# Another stemmer

# %%
from nltk.stem import SnowballStemmer
sbst = SnowballStemmer('english')
for words in words_to_stem:
    print(words+':'+sbst.stem(words))
# Out:
# give:give
# giving:give
# given:given
# gave:gave

# %% [markdown]
# Lemmatization
